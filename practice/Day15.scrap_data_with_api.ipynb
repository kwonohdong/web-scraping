# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup

# %%
ch_driver = webdriver.Chrome("C:\Program Files (x86)\chromedriver_win32\chromedriver.exe")

# %%
ch_driver.get("https://www.seoul.go.kr/realmnews/in/list.do")

# %%
news_items = ch_driver.find_elements_by_class_name("item")

# %%
news_items[0].text
# Out:
# '[20753] 판교 더샵 포레스트 서울시 장애인 특별공급 기관추천 대상자 공고\n2018-12-19 15:20:48 [복지]\n판교 더샵 포레스트 기관추천 대상자 공고'

# %%
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")

ch_driver = webdriver.Chrome('C:\Program Files (x86)\chromedriver_win32\chromedriver.exe', chrome_options=options)
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: use options instead of chrome_options
#   import sys

# %%
driver.get("https://www.seoul.go.kr/realmnews/in/list.do")

# %%
news_items = driver.find_elements_by_class_name("item")

# %%
news_items[0].text
# Out:
# '[20753] 판교 더샵 포레스트 서울시 장애인 특별공급 기관추천 대상자 공고\n2018-12-19 15:20:48 [복지]\n판교 더샵 포레스트 기관추천 대상자 공고'

# %% [markdown]
# ## Scrap data with api
#
# JSONView - Chrome Web Store 에서 설치해서 사용하면 좋음.
#
# ※ 개발자도구 > Network 탭에서 정보들을 살펴보고 전달되는 데이터 형식을 확인
# iframe 을 사용하거나, JS 사용되거나 하는경우엔 selenium 을 사용하고, 그 외에는 BeautifulSoup 을 사용.

# %%
edx_da_search_url = 'https://www.edx.org/api/v1/catalog/search?subject_uuids=a168a80a-4b6c-4d92-9f1d-4c235206feaf&do_not_retrieve_all=true&page_size=12'

# %%
response = requests.get(edx_da_search_url)

# %%
response.json()
# Out:
# {'dates': [],
#  'queries': {'availability_archived': {'count': 144,
#    'distinct_count': 133,
#    'query_string': 'selected_query_facets[]=availability_archived',
#    'url': 'https://www.edx.org/api/v1/catalog/search?selected_query_facets[]=availability_archived&page=1&page_size=12&partner=edx&hidden=0&content_type[]=courserun&content_type[]=program&subject_uuids=a168a80a-4b6c-4d92-9f1d-4c235206feaf'},
#   'availability_starting_soon': {'count': 61,
#    'distinct_count': 61,
#    'query_string': 'selected_query_facets[]=availability_starting_soon',
#    'url': 'https://www.edx.org/api/v1/catalog/search?selected_query_facets[]=availability_starting_soon&page=1&page_size=12&partner=edx&hidden=0&content_type[]=courserun&content_type[]=program&subject_uuids=a168a80a-4b6c-4d92-9f1d-4c235206feaf'},
#   'availability_upcoming': {'count': 23,
#    'distinct_count': 21,
#    'query_string': 'selected_query_facets[]=availability_upcoming',
# ...

# %%
zigbang_search_url = 'https://apis.zigbang.com/v3/items?detail=true&item_ids=[14120945,13486260,14220693,13434744,13511112,14146370,14200218,14217196,14148622,14067100,13415919,14093748,14186335,14166959,14099918,14220255,14192682,14075648,14226960,13466551,14094071,14236343,14184698,14235207,14221873,14201111,14184519,14202130,14099314,14085001,14123079,14210761,14194295,14166474,13483199,14198638,14099155,14186634,14145427,14166935,14132076,14216072,14066940,14200058,14143906,13531037,13419337,13494995,13535118,14199730,14152146,14207364,14225160,13426085,14195264,14157923,13410562,14153131,14206501,14149489]'

# %%
response = requests.get(zigbang_search_url)

# %%
search_list = response.json().get('items')
search_list[0].get('item')
# Out:
# {'id': 14120945,
#  'images': [{'index': 0,
#    'count': 1,
#    'url': 'https://ic.zigbang.com/ic/items/14120945/1.jpg'},
#   {'index': 1,
#    'count': 2,
#    'url': 'https://ic.zigbang.com/ic/items/14120945/2.jpg'},
#   {'index': 2,
#    'count': 3,
#    'url': 'https://ic.zigbang.com/ic/items/14120945/3.jpg'},
#   {'index': 3,
#    'count': 4,
#    'url': 'https://ic.zigbang.com/ic/items/14120945/4.jpg'},
#   {'index': 4,
#    'count': 5,
#    'url': 'https://ic.zigbang.com/ic/items/14120945/5.jpg'},
#   {'index': 5,
#    'count': 6,
#    'url': 'https://ic.zigbang.com/ic/items/14120945/6.jpg'},
#   {'index': 6,
#    'count': 7,
#    'url': 'https://ic.zigbang.com/ic/items/14120945/7.jpg'}],
#  'is_realestate': True,
#  'is_direct': False,
#  'is_room': False,
#  'is_type_room': False,
#  'rent': 40,
#  'deposit': 1000,
#  'is_deposit_only': False,
#  'floor': '3층',
#  '_floor': '3층',
#  'floor_all': '5층',
#  'local1': '서울시',
#  'local2': '마포구',
#  'local3': '연남동',
# ...

# %%
search_list[0].get('item').keys()
# Out:
# dict_keys(['id', 'images', 'is_realestate', 'is_direct', 'is_room', 'is_type_room', 'rent', 'deposit', 'is_deposit_only', 'floor', '_floor', 'floor_all', 'local1', 'local2', 'local3', 'title', 'room_type', 'room_type_code', 'building_type', 'room_gubun_code', 'status', 'is_status_open', 'is_status_close', 'view_count', 'updated_at', 'updated_at2', 'read_updated_at', 'size_m2', 'size', 'size_m2_contract', 'size_contract', 'address1', 'near_subways', 'random_location', 'options', 'manage_cost', 'manage_cost_inc', 'parking', 'elevator', 'movein_date', 'description', 'description_og', 'pets_text', 'loan_text', 'room_direction_text', 'is_owner', 'images_thumbnail', 'is_zzim', 'secret_memo', 'user_no', 'user_has_penalty', 'user_has_no_penalty', 'user_name', 'user_phone', 'original_user_phone', 'user_mobile', 'user_email', 'user_intro', 'agent_name', 'agent_no', 'agent_phone', 'agent_mobile', 'agent_email', 'agent_local1', 'agent_local2', 'agent_address1', 'agent_lng', 'agent_lat', 'buildin
# ...
